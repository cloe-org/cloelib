# %%
import cloelib.observables.clusters
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-288157cb028b> in <module>
# ----> 1 import cloelib.observables.clusters
#
# ModuleNotFoundError: No module named 'cloelib'
